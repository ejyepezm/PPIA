# %% [markdown]
# <a href="https://colab.research.google.com/github/ejyepezm/PPIA/blob/main/unidad_1_fundamentos_vectorizacion/1_Estructuras_Mutabilidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 💊 Cápsula 1: La Trampa de la Mutabilidad
# **Tema:** Gestión de Memoria, Listas vs Tuplas y Sets.

# %% [markdown]
# ## 1. Las variables en Python NO son cajas
#
# En otros lenguajes, una variable es una caja donde guardas un valor. En Python, **una variable es una ETIQUETA (Pointer)** que pegas a un objeto en memoria.
#
# ### El "Bug Fantasma" (Aliasing)
# Si haces `lista_A = [1, 2, 3]` y luego `lista_B = lista_A`, **NO** has creado una copia. Has puesto dos etiquetas al **mismo objeto**. Si cambias B, cambiará A. Esto causa bugs terribles en producción.
#
# ### Mutabilidad vs Inmutabilidad
# *   **Mutables (Listas `[]`, Diccionarios `{}`):** Se pueden modificar después de creados. Son flexibles pero peligrosos si no tienes cuidado.
# *   **Inmutables (Tuplas `()`, Strings `""`):** Una vez creados, son piedra. Nadie puede alterarlos. Son **seguros** para datos críticos (como coordenadas, IDs, configuración).
#
# ### Sets (Conjuntos `{}`)
# Matemáticas puras. No tienen orden, pero **no admiten duplicados** y buscar dentro de ellos es extremadamente rápido.

# %%
# --- DEMOSTRACIÓN: El peligro de las referencias ---

print("--- 1. EL BUG FANTASMA ---")
# El Inventario Original
inventario_tienda = ["Manzanas", "Peras", "Uvas"]

# El empleado nuevo hace una "copia" para trabajar
inventario_empleado = inventario_tienda

# El empleado vende las Manzanas (las quita de su lista)
inventario_empleado.remove("Manzanas")

print(f"Inventario Empleado: {inventario_empleado}")
print(f"Inventario Tienda:   {inventario_tienda}")
# 😱 ¡DESASTRE! Se borraron de la tienda original.
# ¿Por qué? Porque ambas variables apuntan al MISMO objeto en memoria.

print("\n--- 2. LA SOLUCIÓN (Copia Real) ---")
lista_a = [1, 2, 3]
lista_b = lista_a.copy() # <--- La forma correcta
lista_b.append(99)

print(f"Lista A (Intacta): {lista_a}")
print(f"Lista B (Modif.):  {lista_b}")

print("\n--- 3. LA SEGURIDAD DE LA TUPLA ---")
coordenadas_seguras = (10.5, -74.2) # Paréntesis
try:
    coordenadas_seguras[0] = 99.9
except TypeError as e:
    print(f"❌ Error esperado: {e}")
    print("¡La tupla protegió los datos!")
# Out:
# --- 1. EL BUG FANTASMA ---
# Inventario Empleado: ['Peras', 'Uvas']
# Inventario Tienda:   ['Peras', 'Uvas']
#
# --- 2. LA SOLUCIÓN (Copia Real) ---
# Lista A (Intacta): [1, 2, 3]
# Lista B (Modif.):  [1, 2, 3, 99]
#
# --- 3. LA SEGURIDAD DE LA TUPLA ---
# ❌ Error esperado: 'tuple' object does not support item assignment
# ¡La tupla protegió los datos!

# %% [markdown]
# ## 🔥 Micro-Desafío: Sistema de Coordenadas de Drones
#
# Trabajas en una empresa de drones. Recibes una lista de coordenadas de vuelo, pero hay dos problemas graves:
# 1.  **Datos Sucios:** Hay coordenadas duplicadas (el dron pasaría dos veces por el mismo sitio).
# 2.  **Seguridad:** Las coordenadas están en una Lista, por lo que cualquier hacker (o junior dev) podría modificarlas en vuelo.
#
# **Tu Misión:**
# 1.  Elimina los duplicados instantáneamente usando un **Set**.
# 2.  Convierte la colección final en una **Tupla** para "congelar" los datos y hacerlos inmutables (Read-Only).
# 3.  Imprime el tipo de dato final para verificar.

# %%
# Datos recibidos del satélite (con duplicados)
# Formato: [latitud, longitud]
ruta_vuelo_sucia = [
    (40.71, -74.00), # New York
    (34.05, -118.24), # Los Angeles
    (40.71, -74.00), # DUPLICADO
    (51.50, -0.12),  # Londres
    (34.05, -118.24) # DUPLICADO
]

print(f"Ruta sucia ({len(ruta_vuelo_sucia)} puntos): {ruta_vuelo_sucia}")

# --- TU CÓDIGO AQUÍ ---

# 1. Elimina duplicados convirtiendo a Set
ruta_unica = None # TODO: Cambia esto

# 2. Convierte a Tupla para hacerla inmutable
ruta_final_segura = None # TODO: Cambia esto

# Verificación
print(f"\nRuta Final ({len(ruta_final_segura)} puntos): {ruta_final_segura}")
print(f"Tipo de dato: {type(ruta_final_segura)}")

# Validación automática
if isinstance(ruta_final_segura, tuple) and len(ruta_final_segura) == 3:
    print("\n✅ ¡Éxito! La ruta está optimizada y asegurada.")
else:
    print("\n❌ Algo falló. Revisa que sea una Tupla y no tenga duplicados.")
# Out:
# Ruta sucia (5 puntos): [(40.71, -74.0), (34.05, -118.24), (40.71, -74.0), (51.5, -0.12), (34.05, -118.24)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3154670136.py in <cell line: 0>()
#      20
#      21 # Verificación
# ---> 22 print(f"\nRuta Final ({len(ruta_final_segura)} puntos): {ruta_final_segura}")
#      23 print(f"Tipo de dato: {type(ruta_final_segura)}")
#      24
#
# TypeError: object of type 'NoneType' has no len()
